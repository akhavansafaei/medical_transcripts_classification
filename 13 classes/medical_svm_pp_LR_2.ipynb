# %%
# !pip install kaggle

# %%
from google.colab import files

# Upload your Kaggle API key file
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3c588dcd-25ba-429d-afb1-578257726670" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3c588dcd-25ba-429d-afb1-578257726670">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d tboyle10/medicaltranscriptions
# Out:
# ...
#   0% 0.00/4.85M [00:00<?, ?B/s]
# 100% 4.85M/4.85M [00:00<00:00, 191MB/s]

# %%
# !unzip medicaltranscriptions.zip
# Out:
# Archive:  medicaltranscriptions.zip
#   inflating: mtsamples.csv

# %%
import pandas as pd

# Read the CSV file (adjust the filename if necessary)
df = pd.read_csv('mtsamples.csv')

# Now you can work with the DataFrame 'df'

# %%
df.head()
# Out:
#    Unnamed: 0                                        description  \
# 0           0   A 23-year-old white female presents with comp...
# 1           1           Consult for laparoscopic gastric bypass.
# 2           2           Consult for laparoscopic gastric bypass.
# 3           3                             2-D M-Mode. Doppler.
# 4           4                                 2-D Echocardiogram
#
#              medical_specialty                                sample_name  \
# 0         Allergy / Immunology                         Allergic Rhinitis
# 1                   Bariatrics   Laparoscopic Gastric Bypass Consult - 2
# 2                   Bariatrics   Laparoscopic Gastric Bypass Consult - 1
# 3   Cardiovascular / Pulmonary                    2-D Echocardiogram - 1
# 4   Cardiovascular / Pulmonary                    2-D Echocardiogram - 2
#
#                                        transcription  \
# 0  SUBJECTIVE:,  This 23-year-old white female pr...
# ...

# %%
import pandas as pd

# Assuming you have already read the dataset into the 'df' DataFrame

# Group by the "medical_specialty" column and count occurrences
specialty_counts = df['medical_specialty'].value_counts()

# Display the counts
print(specialty_counts)
# Out:
#  Surgery                          1103
#  Consult - History and Phy.        516
#  Cardiovascular / Pulmonary        372
#  Orthopedic                        355
#  Radiology                         273
#  General Medicine                  259
#  Gastroenterology                  230
#  Neurology                         223
#  SOAP / Chart / Progress Notes     166
#  Obstetrics / Gynecology           160
#  Urology                           158
#  Discharge Summary                 108
#  ENT - Otolaryngology               98
#  Neurosurgery                       94
#  Hematology - Oncology              90
#  Ophthalmology                      83
#  Nephrology                         81
#  Emergency Room Reports             75
#  Pediatrics - Neonatal              70
#  Pain Management                    62
#  Psychiatry / Psychology            53
#  Office Notes                       51
#  Podiatry                           47
#  Dermatology                        29
# ...

# %%
data=df[['transcription','medical_specialty']]

# %%
data.isna().sum()

# %%
data=data.dropna()

# %%
import pandas as pd

# Assuming you already have a DataFrame 'data'

# Add a new column 'index' with values ranging from 0 to the length of the DataFrame
data['index'] = range(len(data))
# Out:
# <ipython-input-45-713a30ccc943>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['index'] = range(len(data))

# %%
data.rename(columns={'medical_specialty': 'label','transcription':'text'}, inplace=True)
# Out:
# <ipython-input-46-43785834f2fc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.rename(columns={'medical_specialty': 'label','transcription':'text'}, inplace=True)

# %%
data.head()
# Out:
#                                                 text  \
# 0  SUBJECTIVE:,  This 23-year-old white female pr...
# 1  PAST MEDICAL HISTORY:, He has difficulty climb...
# 2  HISTORY OF PRESENT ILLNESS: , I have seen ABC ...
# 3  2-D M-MODE: , ,1.  Left atrial enlargement wit...
# 4  1.  The left ventricular cavity size and wall ...
#
#                          label  index
# 0         Allergy / Immunology      0
# 1                   Bariatrics      1
# 2                   Bariatrics      2
# 3   Cardiovascular / Pulmonary      3
# 4   Cardiovascular / Pulmonary      4

# %%
from sklearn.preprocessing import LabelEncoder

# Assuming you have already renamed the "medical_specialty" column to "label"

# Create a LabelEncoder instance
label_encoder = LabelEncoder()

# Fit the encoder to your unique labels and transform the "label" column
data['label_index'] = label_encoder.fit_transform(data['label'])

# The "label_index" column now contains index values corresponding to the labels
data.head()
# Out:
#                                                 text  \
# 0  SUBJECTIVE:,  This 23-year-old white female pr...
# 1  PAST MEDICAL HISTORY:, He has difficulty climb...
# 2  HISTORY OF PRESENT ILLNESS: , I have seen ABC ...
# 3  2-D M-MODE: , ,1.  Left atrial enlargement wit...
# 4  1.  The left ventricular cavity size and wall ...
#
#                          label  index  label_index
# 0         Allergy / Immunology      0            0
# 1                   Bariatrics      1            2
# 2                   Bariatrics      2            2
# 3   Cardiovascular / Pulmonary      3            3
# 4   Cardiovascular / Pulmonary      4            3

# %%
# Fit the encoder to your unique labels
label_encoder.fit(data['label'])

# Create a dictionary mapping labels to their encoded values
label_encoding_dict = {label: encoded_value for label, encoded_value in zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_))}

# %%
print(label_encoding_dict)
# Out:
# {' Allergy / Immunology': 0, ' Autopsy': 1, ' Bariatrics': 2, ' Cardiovascular / Pulmonary': 3, ' Chiropractic': 4, ' Consult - History and Phy.': 5, ' Cosmetic / Plastic Surgery': 6, ' Dentistry': 7, ' Dermatology': 8, ' Diets and Nutritions': 9, ' Discharge Summary': 10, ' ENT - Otolaryngology': 11, ' Emergency Room Reports': 12, ' Endocrinology': 13, ' Gastroenterology': 14, ' General Medicine': 15, ' Hematology - Oncology': 16, ' Hospice - Palliative Care': 17, ' IME-QME-Work Comp etc.': 18, ' Lab Medicine - Pathology': 19, ' Letters': 20, ' Nephrology': 21, ' Neurology': 22, ' Neurosurgery': 23, ' Obstetrics / Gynecology': 24, ' Office Notes': 25, ' Ophthalmology': 26, ' Orthopedic': 27, ' Pain Management': 28, ' Pediatrics - Neonatal': 29, ' Physical Medicine - Rehab': 30, ' Podiatry': 31, ' Psychiatry / Psychology': 32, ' Radiology': 33, ' Rheumatology': 34, ' SOAP / Chart / Progress Notes': 35, ' Sleep Medicine': 36, ' Speech - Language': 37, ' Surgery': 38, ' Urology': 39}

# %%
data.rename(columns={'label': 'medical_specialty','label_index':'label'}, inplace=True)
data.head()
# Out:
#                                                 text  \
# 0  SUBJECTIVE:,  This 23-year-old white female pr...
# 1  PAST MEDICAL HISTORY:, He has difficulty climb...
# 2  HISTORY OF PRESENT ILLNESS: , I have seen ABC ...
# 3  2-D M-MODE: , ,1.  Left atrial enlargement wit...
# 4  1.  The left ventricular cavity size and wall ...
#
#              medical_specialty  index  label
# 0         Allergy / Immunology      0      0
# 1                   Bariatrics      1      2
# 2                   Bariatrics      2      2
# 3   Cardiovascular / Pulmonary      3      3
# 4   Cardiovascular / Pulmonary      4      3

# %%
#data['decoded_label'] = label_encoder.inverse_transform(data['label'])
#data.head()

# %%
import pandas as pd
import string
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer

nltk.download('stopwords')
nltk.download('wordnet')

def preprocess_column(df, column_name):
    # Remove punctuation
    def remove_punctuation(text):
        j=" "
        punctuation_free =  "".join([" " if i in string.punctuation else i for i in text]) #"".join([i for i in text if i not in string.punctuation ])
        return punctuation_free

    df_copy = df.copy()
    df_copy['clean_' + column_name] = df_copy[column_name].apply(lambda x: remove_punctuation(x))

    # Convert to lowercase
    df_copy['clean_' + column_name] = df_copy['clean_' + column_name].apply(lambda x: x.lower())

    # Remove stopwords
    stop_words_list = stopwords.words('english')
    def remove_stopwords(text):
        words = text.split()
        meaningful_words = [word for word in words if word.lower() not in stop_words_list]
        return " ".join(meaningful_words)

    df_copy['clean_' + column_name] = df_copy['clean_' + column_name].apply(remove_stopwords)

    # Apply stemming
    porter_stemmer = PorterStemmer()
    def stemming(text):
        words = text.split()
        stem_text = [porter_stemmer.stem(word) for word in words]
        return " ".join(stem_text)

    df_copy['stemmed_' + column_name] = df_copy['clean_' + column_name].apply(stemming)

    # Apply lemmatization
    wordnet_lemmatizer = WordNetLemmatizer()
    def lemmatizer(text):
        words = text.split()
        lemm_text = [wordnet_lemmatizer.lemmatize(word) for word in words]
        return " ".join(lemm_text)

    df_copy['lemmatized_' + column_name] = df_copy['clean_' + column_name].apply(lemmatizer)

    return df_copy
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
data['text'] = data['text'].astype(str)

# %%
preprocessed_data = preprocess_column(data, 'text')
(preprocessed_data.head())
# Out:
#                                                 text  \
# 0  SUBJECTIVE:,  This 23-year-old white female pr...
# 1  PAST MEDICAL HISTORY:, He has difficulty climb...
# 2  HISTORY OF PRESENT ILLNESS: , I have seen ABC ...
# 3  2-D M-MODE: , ,1.  Left atrial enlargement wit...
# 4  1.  The left ventricular cavity size and wall ...
#
#              medical_specialty  index  label  \
# 0         Allergy / Immunology      0      0
# 1                   Bariatrics      1      2
# 2                   Bariatrics      2      2
# 3   Cardiovascular / Pulmonary      3      3
# 4   Cardiovascular / Pulmonary      4      3
#
#                                           clean_text  \
# 0  subjective 23 year old white female presents c...
# 1  past medical history difficulty climbing stair...
# 2  history present illness seen abc today pleasan...
# 3  2 mode 1 left atrial enlargement left atrial d...
# 4  1 left ventricular cavity size wall thickness ...
#
# ...

# %%
data['text'][1]
# Out:
# 'PAST MEDICAL HISTORY:, He has difficulty climbing stairs, difficulty with airline seats, tying shoes, used to public seating, and lifting objects off the floor.  He exercises three times a week at home and does cardio.  He has difficulty walking two blocks or five flights of stairs.  Difficulty with snoring.  He has muscle and joint pains including knee pain, back pain, foot and ankle pain, and swelling.  He has gastroesophageal reflux disease.,PAST SURGICAL HISTORY:, Includes reconstructive surgery on his right hand 13 years ago.  ,SOCIAL HISTORY:, He is currently single.  He has about ten drinks a year.  He had smoked significantly up until several months ago.  He now smokes less than three cigarettes a day.,FAMILY HISTORY:, Heart disease in both grandfathers, grandmother with stroke, and a grandmother with diabetes.  Denies obesity and hypertension in other family members.,CURRENT MEDICATIONS:, None.,ALLERGIES:,  He is allergic to Penicillin.,MISCELLANEOUS/EATING HISTORY:, He has
# ...

# %%
preprocessed_data['lemmatized_text'][1]
# Out:
# 'past medical history difficulty climbing stair difficulty airline seat tying shoe used public seating lifting object floor exercise three time week home cardio difficulty walking two block five flight stair difficulty snoring muscle joint pain including knee pain back pain foot ankle pain swelling gastroesophageal reflux disease past surgical history includes reconstructive surgery right hand 13 year ago social history currently single ten drink year smoked significantly several month ago smoke le three cigarette day family history heart disease grandfather grandmother stroke grandmother diabetes denies obesity hypertension family member current medication none allergy allergic penicillin miscellaneous eating history going support group seven month lynn holmberg greenwich eastchester new york feel appropriate program poor experience greenwich program eating history emotional eater like sweet like big portion carbohydrate like chicken steak currently weighs 312 pound ideal body weigh
# ...

# %%
data['text'][0]
# Out:
# 'SUBJECTIVE:,  This 23-year-old white female presents with complaint of allergies.  She used to have allergies when she lived in Seattle but she thinks they are worse here.  In the past, she has tried Claritin, and Zyrtec.  Both worked for short time but then seemed to lose effectiveness.  She has used Allegra also.  She used that last summer and she began using it again two weeks ago.  It does not appear to be working very well.  She has used over-the-counter sprays but no prescription nasal sprays.  She does have asthma but doest not require daily medication for this and does not think it is flaring up.,MEDICATIONS: , Her only medication currently is Ortho Tri-Cyclen and the Allegra.,ALLERGIES: , She has no known medicine allergies.,OBJECTIVE:,Vitals:  Weight was 130 pounds and blood pressure 124/78.,HEENT:  Her throat was mildly erythematous without exudate.  Nasal mucosa was erythematous and swollen.  Only clear drainage was seen.  TMs were clear.,Neck:  Supple without adenopathy
# ...

# %%
preprocessed_data['lemmatized_text'][0]
# Out:
# 'subjective 23 year old white female present complaint allergy used allergy lived seattle think worse past tried claritin zyrtec worked short time seemed lose effectiveness used allegra also used last summer began using two week ago appear working well used counter spray prescription nasal spray asthma doest require daily medication think flaring medication medication currently ortho tri cyclen allegra allergy known medicine allergy objective vitals weight 130 pound blood pressure 124 78 heent throat mildly erythematous without exudate nasal mucosa erythematous swollen clear drainage seen tm clear neck supple without adenopathy lung clear assessment allergic rhinitis plan 1 try zyrtec instead allegra another option use loratadine think prescription coverage might cheaper 2 sample nasonex two spray nostril given three week prescription written well'

# %%
preprocessed_data=preprocessed_data[['index','lemmatized_text','label','text']]

# %%
data=preprocessed_data

# %%
data.rename(columns={'lemmatized_text': 'ptext'}, inplace=True)
data.head()
# Out:
# <ipython-input-200-db9ff9a0f7c4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.rename(columns={'lemmatized_text': 'ptext'}, inplace=True)
#    index                                              ptext  label  \
# 0      0  subjective 23 year old white female present co...      0
# 1      1  past medical history difficulty climbing stair...      2
# 2      2  history present illness seen abc today pleasan...      2
# 3      3  2 mode 1 left atrial enlargement left atrial d...      3
# 4      4  1 left ventricular cavity size wall thickness ...      3
#
#                                                 text
# 0  SUBJECTIVE:,  This 23-year-old white female pr...
# 1  PAST MEDICAL HISTORY:, He has difficulty climb...
# 2  HISTORY OF PRESENT ILLNESS: , I have seen ABC ...
# ...

# %%
from sklearn.model_selection import train_test_split

# Assuming you have a DataFrame 'data' with a 'label_index' column containing label indices

# Split the data into training and test sets with stratified sampling
X_train, X_test, y_train, y_test = train_test_split(
    data[['text','ptext','index']],  # Features (TF-IDF vectors)
    data[['label','index']],      # Target variable (label indices)
    test_size=0.2,
    stratify=data['label'],  # Ensure stratified sampling based on label indices
    random_state=48  # Set a random seed for reproducibility
)

# %%
# Merge X_train and y_train into the train DataFrame based on 'index' column
train = X_train.merge(y_train )

# Merge X_test and y_test into the test DataFrame based on 'index' column
test = X_test.merge(y_test)

# Now, the 'train' and 'test' DataFrames are merged based on the 'index' column

# %%
train.head()
# Out:
#                                                 text  \
# 0  ADMITTING DIAGNOSES:,1.  Bradycardia.,2.  Dizz...
# 1  HISTORY OF PRESENT ILLNESS:,  History as provi...
# 2  CHIEF COMPLAINT: , Nausea and feeling faint.,H...
# 3  NAME OF PROCEDURE: , Left heart catheterizatio...
# 4  PROCEDURES PERFORMED:,1.  DDDR permanent pacem...
#
#                                                ptext  index  label
# 0  admitting diagnosis 1 bradycardia 2 dizziness ...   3384     15
# 1  history present illness history provided prima...   3079     17
# 2  chief complaint nausea feeling faint hpi patie...   3784     12
# 3  name procedure left heart catheterization vent...   4744      3
# 4  procedure performed 1 dddr permanent pacemaker...    912     38

# %%
test.head()
# Out:
#                                                 text  \
# 0  REASON FOR CONSULTATION: , Lethargy.,HISTORY O...
# 1  CC:, Left third digit numbness and wrist pain....
# 2  Thereafter, he was evaluated and it was felt t...
# 3  PREOPERATIVE DIAGNOSIS: , Right pleural mass.,...
# 4  OPERATIVE PROCEDURE:,1.  Redo coronary bypass ...
#
#                                                ptext  index  label
# 0  reason consultation lethargy history present i...   1768     32
# 1  cc left third digit numbness wrist pain hx 44 ...   1569     33
# 2  thereafter evaluated felt reconstruction relat...   3064     18
# 3  preoperative diagnosis right pleural mass post...   3144     16
# 4  operative procedure 1 redo coronary bypass gra...   1097     38

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#train.to_csv('/content/drive/MyDrive/train.csv')
#test.to_csv('/content/drive/MyDrive/test.csv')

# %% [markdown]
# # Define the label to number mapping dictionary
# label_to_number = {
#     ' Allergy / Immunology': 0,
#     ' Autopsy': 1,
#     ' Bariatrics': 2,
#     ' Cardiovascular / Pulmonary': 3,
#     ' Chiropractic': 4,
#     ' Consult - History and Phy.': 5,
#     ' Cosmetic / Plastic Surgery': 6,
#     ' Dentistry': 7,
#     ' Dermatology': 8,
#     ' Diets and Nutritions': 9,
#     ' Discharge Summary': 10,
#     ' ENT - Otolaryngology': 11,
#     ' Emergency Room Reports': 12,
#     ' Endocrinology': 13,
#     ' Gastroenterology': 14,
#     ' General Medicine': 15,
#     ' Hematology - Oncology': 16,
#     ' Hospice - Palliative Care': 17,
#     ' IME-QME-Work Comp etc.': 18,
#     ' Lab Medicine - Pathology': 19,
#     ' Letters': 20,
#     ' Nephrology': 21,
#     ' Neurology': 22,
#     ' Neurosurgery': 23,
#     ' Obstetrics / Gynecology': 24,
#     ' Office Notes': 25,
#     ' Ophthalmology': 26,
#     ' Orthopedic': 27,
#     ' Pain Management': 28,
#     ' Pediatrics - Neonatal': 29,
#     ' Physical Medicine - Rehab': 30,
#     ' Podiatry': 31,
#     ' Psychiatry / Psychology': 32,
#     ' Radiology': 33,
#     ' Rheumatology': 34,
#     ' SOAP / Chart / Progress Notes': 35,
#     ' Sleep Medicine': 36,
#     ' Speech - Language': 37,
#     ' Surgery': 38,
#     ' Urology': 39
# }

# %%
# Define the label to number mapping dictionary
label_to_number = {
    ' Allergy / Immunology': 0,
    ' Autopsy': 1,
    ' Bariatrics': 2,
    ' Cardiovascular / Pulmonary': 3,
    ' Chiropractic': 4,
    ' Consult - History and Phy.': 5,
    ' Cosmetic / Plastic Surgery': 6,
    ' Dentistry': 7,
    ' Dermatology': 8,
    ' Diets and Nutritions': 9,
    ' Discharge Summary': 10,
    ' ENT - Otolaryngology': 11,
    ' Emergency Room Reports': 12,
    ' Endocrinology': 13,
    ' Gastroenterology': 14,
    ' General Medicine': 15,
    ' Hematology - Oncology': 16,
    ' Hospice - Palliative Care': 17,
    ' IME-QME-Work Comp etc.': 18,
    ' Lab Medicine - Pathology': 19,
    ' Letters': 20,
    ' Nephrology': 21,
    ' Neurology': 22,
    ' Neurosurgery': 23,
    ' Obstetrics / Gynecology': 24,
    ' Office Notes': 25,
    ' Ophthalmology': 26,
    ' Orthopedic': 27,
    ' Pain Management': 28,
    ' Pediatrics - Neonatal': 29,
    ' Physical Medicine - Rehab': 30,
    ' Podiatry': 31,
    ' Psychiatry / Psychology': 32,
    ' Radiology': 33,
    ' Rheumatology': 34,
    ' SOAP / Chart / Progress Notes': 35,
    ' Sleep Medicine': 36,
    ' Speech - Language': 37,
    ' Surgery': 38,
    ' Urology': 39
}

# List of medical specialties with matching labels
medical_specialties = [
    ' Surgery',
    ' Consult - History and Phy.',
    ' Cardiovascular / Pulmonary',
    ' Orthopedic',
    ' Radiology',
    ' General Medicine',
    ' Gastroenterology',
    ' Neurology',
    ' SOAP / Chart / Progress Notes',
    ' Obstetrics / Gynecology',
    ' Urology',
    ' Discharge Summary'
]

# Create a list of numbers corresponding to the medical specialties
specialty_numbers = [label_to_number[specialty] for specialty in medical_specialties]

# The `specialty_numbers` list contains the numerical representations of the medical specialties
print(specialty_numbers)
specialty_numbers=[38, 5, 3, 27, 33, 15, 14, 22, 35, 24, 39, 10]
# Out:
# [38, 5, 3, 27, 33, 15, 14, 22, 35, 24, 39, 10]

# %%
import pandas as pd

# Load the train and test CSV files
train = pd.read_csv('/content/drive/My Drive/train.csv')
test = pd.read_csv('/content/drive/My Drive/test.csv')
train=train[['text','ptext','index','label']]
test=test[['text','ptext','index','label']]
# List of categories
medical_specialties = [
    "Surgery",
    "Consult - History and Phy.",
    "Cardiovascular / Pulmonary",
    "Orthopedic",
    "Radiology",
    "General Medicine",
    "Gastroenterology",
    "Neurology",
    "SOAP / Chart / Progress Notes",
    "Obstetrics / Gynecology",
    "Urology",
    "Discharge Summary"
]
categories=[ ]
# Iterate through the 'label' column of train, test, and valid dataframes
for df in [train, test]:
    df['label'] = df['label'].apply(lambda x: x if x in specialty_numbers else 40)

# Now, the 'label' column in train, test, and valid contains only values in 'categories' or 'others'

# Extract features (X) and labels (y) for train and test datasets
X_train = train[['text', 'ptext']]
y_train = train['label']

X_test = test[['text', 'ptext']]
y_test = test['label']
# Out:
# <ipython-input-55-cfee3002d0bf>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['label'] = df['label'].apply(lambda x: x if x in specialty_numbers else 40)

# %%
import pandas as pd

# Assuming you have already read the dataset into the 'df' DataFrame

# Group by the "medical_specialty" column and count occurrences
specialty_counts = train['label'].value_counts()

# Display the counts
print(specialty_counts)
# Out:
# 38    870
# 40    858
# 5     413
# 3     297
# 27    284
# 33    218
# 15    207
# 14    179
# 22    178
# 35    133
# 39    125
# 24    124
# 10     86
# Name: label, dtype: int64

# %%
import pandas as pd

# Assuming you have already read the dataset into the 'df' DataFrame

# Group by the "medical_specialty" column and count occurrences
specialty_counts = test['label'].value_counts()

# Display the counts
print(specialty_counts)
# Out:
# 38    218
# 40    214
# 5     103
# 3      74
# 27     71
# 33     55
# 15     52
# 14     45
# 22     45
# 35     33
# 24     31
# 39     31
# 10     22
# Name: label, dtype: int64

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Assuming you have already renamed the "medical_specialty" column to "label"

# Create a LabelEncoder instance
label_encoder = LabelEncoder()

# Fit the encoder to your unique labels and transform the "label" column

# Load the train and test CSV files
train = pd.read_csv('/content/drive/My Drive/training.csv')
valid=pd.read_csv('/content/drive/My Drive/validation.csv')
test = pd.read_csv('/content/drive/My Drive/test.csv')
# List of categories
categories = [
    "Surgery",
    "Consult - History and Phy.",
    "Cardiovascular / Pulmonary",
    "Orthopedic",
    "Radiology",
    "General Medicine",
    "Gastroenterology",
    "Neurology",
    "SOAP / Chart / Progress Notes",
    "Obstetrics / Gynecology",
    "Urology",
    "Discharge Summary"
]
specialty_numbers=[38, 5, 3, 27, 33, 15, 14, 22, 35, 24, 39, 10]

# Iterate through the 'label' column of train, test, and valid dataframes
for df in [train, test, valid]:
    df['label'] = df['label'].apply(lambda x: x if x in specialty_numbers else 40)
    df['label'] = label_encoder.fit_transform(df['label'])

train=train[['text','ptext','index','label']]
valid=valid[['text','ptext','index','label']]
test=test[['text','ptext','index','label']]
# Extract features (X) and labels (y) for train and test datasets
X_train = train[['text', 'ptext']]
y_train = train['label']

X_valid=valid[['text', 'ptext']]
y_valid = valid['label']

X_test = test[['text', 'ptext']]
y_test = test['label']

# %% [markdown]
# # tf-idf vectorizing

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
# Create feature vectors
vectorizer = TfidfVectorizer(min_df = 1, # 5
                             max_df = 0.8,
                             sublinear_tf = True,
                             use_idf = True)

# %%
# Now, you can use the vectorizer on the 'text' column
train_vectors = vectorizer.fit_transform(train['text'])
test_vectors = vectorizer.transform(test['text'])

# %%
train_vectors = vectorizer.fit_transform(train['text'])
test_vectors = vectorizer.transform(test['text'])

# %%
ptrain_vectors = vectorizer.fit_transform(train['ptext'])
ptest_vectors = vectorizer.transform(test['ptext'])

# %% [markdown]
# ##### without pp

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# Create an SVM classifier
svm_classifier = SVC(kernel='linear')

# Fit the classifier on the training data
svm_classifier.fit(train_vectors, train['label'])

# Predict labels for the test data
predicted_labels = svm_classifier.predict(test_vectors)

# Calculate accuracy on the test set
accuracy = accuracy_score(test['label'], predicted_labels)

print("Accuracy of the SVM model:", accuracy)
# Out:
# Accuracy of the SVM model: 0.2193158953722334

# %%
# Create a DataFrame with a single column for predictions
test_predictions_df = pd.DataFrame({'predictions': predicted_labels})

# Save the DataFrame to a CSV file
test_predictions_df.to_csv('/content/drive/MyDrive/svm_tfid_r.csv', index=False)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# Create a Logistic Regression classifier
logistic_classifier = LogisticRegression()

# Fit the classifier on the training data
logistic_classifier.fit(train_vectors, train['label'])

# Predict labels for the test data
predicted_labels = logistic_classifier.predict(test_vectors)

# Calculate accuracy on the test set
accuracy = accuracy_score(test['label'], predicted_labels)

print("Accuracy of the Logistic Regression model:", accuracy)
# Out:
# Accuracy of the Logistic Regression model: 0.2776659959758551

# %%
# Create a DataFrame with a single column for predictions
test_predictions_df = pd.DataFrame({'predictions': predicted_labels})

# Save the DataFrame to a CSV file
test_predictions_df.to_csv('/content/drive/MyDrive/lr_tfid_r.csv', index=False)

# %% [markdown]
# ###### with pp

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# Create an SVM classifier
svm_classifier = SVC(kernel='linear')

# Fit the classifier on the training data
svm_classifier.fit(ptrain_vectors, train['label'])

# Predict labels for the test data
predicted_labels = svm_classifier.predict(ptest_vectors)

# Calculate accuracy on the test set
accuracy = accuracy_score(test['label'], predicted_labels)

print("Accuracy of the SVM model:", accuracy)
# Out:
# Accuracy of the SVM model: 0.2152917505030181

# %%
# Create a DataFrame with a single column for predictions
test_predictions_df = pd.DataFrame({'predictions': predicted_labels})

# Save the DataFrame to a CSV file
test_predictions_df.to_csv('/content/drive/MyDrive/svm_tfid_pp_r.csv', index=False)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# Create a Logistic Regression classifier
logistic_classifier = LogisticRegression()

# Fit the classifier on the training data
logistic_classifier.fit(ptrain_vectors, train['label'])

# Predict labels for the test data
predicted_labels = logistic_classifier.predict(ptest_vectors)

# Calculate accuracy on the test set
accuracy = accuracy_score(test['label'], predicted_labels)

print("Accuracy of the Logistic Regression model:", accuracy)
# Out:
# Accuracy of the Logistic Regression model: 0.2776659959758551

# %%
# Create a DataFrame with a single column for predictions
test_predictions_df = pd.DataFrame({'predictions': predicted_labels})

# Save the DataFrame to a CSV file
test_predictions_df.to_csv('/content/drive/MyDrive/lr_tfid_pp_r.csv', index=False)

# %% [markdown]
# # CountVectorizer

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import classification_report
vectorizer = CountVectorizer()
features_train = vectorizer.fit_transform(train['text'])
features_test = vectorizer.transform(test['text'])

# %%
pfeatures_train = vectorizer.fit_transform(train['ptext'])
pfeatures_test = vectorizer.transform(test['ptext'])

# %%
print(features_train)
# Out:
#   (0, 1520)	1
#   (0, 6147)	2
#   (0, 3382)	1
#   (0, 6512)	1
#   (0, 6142)	2
#   (0, 9904)	2
#   (0, 1194)	1
#   (0, 14305)	4
#   (0, 6321)	2
#   (0, 6148)	1
#   (0, 18071)	3
#   (0, 18157)	4
#   (0, 19448)	3
#   (0, 19853)	17
#   (0, 17005)	2
#   (0, 13841)	6
#   (0, 9491)	4
#   (0, 14548)	2
#   (0, 12347)	2
#   (0, 9594)	3
#   (0, 16804)	6
#   (0, 17502)	1
#   (0, 15744)	1
#   (0, 6571)	1
#   (0, 14838)	3
#   :	:
#   (3971, 6143)	1
#   (3971, 10619)	1
#   (3971, 12616)	1
#   (3971, 14629)	1
#   (3971, 7979)	1
#   (3971, 11951)	2
#   (3971, 5382)	1
#   (3971, 8141)	1
#   (3971, 2517)	1
#   (3971, 11128)	1
#   (3971, 13679)	1
#   (3971, 9835)	1
#   (3971, 21314)	1
#   (3971, 13481)	1
#   (3971, 1809)	1
#   (3971, 6536)	1
#   (3971, 10523)	1
#   (3971, 20957)	1
#   (3971, 4154)	1
#   (3971, 9071)	1
#   (3971, 620)	1
#   (3971, 13309)	1
#   (3971, 21921)	1
#   (3971, 14499)	1
#   (3971, 7753)	1

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# Create an SVM classifier
svm_classifier = SVC(kernel='linear')

# Fit the classifier on the training data
svm_classifier.fit(features_train, y_train)

# Predict labels for the test data
predicted_labels = svm_classifier.predict(features_test)

# Calculate accuracy on the test set
accuracy = accuracy_score(y_test, predicted_labels)

print("Accuracy of the SVM model:", accuracy)
# Out:
# Accuracy of the SVM model: 0.176056338028169

# %%
# Create a DataFrame with a single column for predictions
test_predictions_df = pd.DataFrame({'predictions': predicted_labels})

# Save the DataFrame to a CSV file
test_predictions_df.to_csv('/content/drive/MyDrive/svm_cv_r.csv', index=False)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# Create a Logistic Regression classifier
logistic_classifier = LogisticRegression()

# Fit the classifier on the training data
logistic_classifier.fit(features_train, train['label'])

# Predict labels for the test data
predicted_labels = logistic_classifier.predict(features_test)

# Calculate accuracy on the test set
accuracy = accuracy_score(test['label'], predicted_labels)

print("Accuracy of the Logistic Regression model:", accuracy)
# Out:
# Accuracy of the Logistic Regression model: 0.2052313883299799
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# Create a DataFrame with a single column for predictions
test_predictions_df = pd.DataFrame({'predictions': predicted_labels})

# Save the DataFrame to a CSV file
test_predictions_df.to_csv('/content/drive/MyDrive/lr_cv_r.csv', index=False)

# %% [markdown]
# # with pp

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# Create an SVM classifier
svm_classifier = SVC(kernel='linear')

# Fit the classifier on the training data
svm_classifier.fit(pfeatures_train, y_train)

# Predict labels for the test data
predicted_labels = svm_classifier.predict(pfeatures_test)

# Calculate accuracy on the test set
accuracy = accuracy_score(y_test, predicted_labels)

print("Accuracy of the SVM model:", accuracy)
# Out:
# Accuracy of the SVM model: 0.17303822937625754

# %%
# Create a DataFrame with a single column for predictions
test_predictions_df = pd.DataFrame({'predictions': predicted_labels})

# Save the DataFrame to a CSV file
test_predictions_df.to_csv('/content/drive/MyDrive/svm_cv_pp_r.csv', index=False)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# Create a Logistic Regression classifier
logistic_classifier = LogisticRegression()

# Fit the classifier on the training data
logistic_classifier.fit(pfeatures_train, train['label'])

# Predict labels for the test data
predicted_labels = logistic_classifier.predict(pfeatures_test)

# Calculate accuracy on the test set
accuracy = accuracy_score(test['label'], predicted_labels)

print("Accuracy of the Logistic Regression model:", accuracy)
# Out:
# Accuracy of the Logistic Regression model: 0.176056338028169
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# Create a DataFrame with a single column for predictions
test_predictions_df = pd.DataFrame({'predictions': predicted_labels})

# Save the DataFrame to a CSV file
test_predictions_df.to_csv('/content/drive/MyDrive/lr_cv_pp_r.csv', index=False)

# %% [markdown]
# # another method using embedding

# %% [markdown]
# # using glove

# %%
# !wget http://nlp.stanford.edu/data/glove.6B.zip
# Out:
# --2023-09-23 07:42:36--  http://nlp.stanford.edu/data/glove.6B.zip
# Resolving nlp.stanford.edu (nlp.stanford.edu)... 171.64.67.140
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://nlp.stanford.edu/data/glove.6B.zip [following]
# --2023-09-23 07:42:36--  https://nlp.stanford.edu/data/glove.6B.zip
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://downloads.cs.stanford.edu/nlp/data/glove.6B.zip [following]
# --2023-09-23 07:42:36--  https://downloads.cs.stanford.edu/nlp/data/glove.6B.zip
# Resolving downloads.cs.stanford.edu (downloads.cs.stanford.edu)... 171.64.64.22
# Connecting to downloads.cs.stanford.edu (downloads.cs.stanford.edu)|171.64.64.22|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 862182613 (822M) [application/zip]
# ...

# %%
# !unzip glove*.zip
# Out:
# Archive:  glove.6B.zip
#   inflating: glove.6B.50d.txt
#   inflating: glove.6B.100d.txt
#   inflating: glove.6B.200d.txt
#   inflating: glove.6B.300d.txt

# %%
import numpy as np
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
# Load pre-trained GloVe word vectors
glove_file = '/content/glove.6B.100d.txt'  # Adjust the filename as needed
word_vectors = {}
with open(glove_file, 'r', encoding='utf-8') as f:
    for line in f:
        values = line.split()
        word = values[0]
        vector = np.array(values[1:], dtype='float32')
        word_vectors[word] = vector

# %%
# Define a function to create text embeddings
def text_to_embedding(text):
    words = text.split()
    embeddings = [word_vectors.get(word, np.zeros(100)) for word in words]  # 100 is the embedding dimension
    # Handle empty or invalid text
    if not embeddings:
        return np.zeros(100)  # Return a zero vector
    return np.mean(embeddings, axis=0)  # Average the word vectors to get the text embedding

# Apply the text_to_embedding function to create embeddings for your text data
X_train_embeddings = np.array([text_to_embedding(text) for text in X_train['text']])
X_test_embeddings = np.array([text_to_embedding(text) for text in X_test['text']])

# Standardize the data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_embeddings)
X_test_scaled = scaler.transform(X_test_embeddings)

# %%
# Create an SVM classifier
svm_classifier = SVC(kernel='linear')

# Fit the classifier on the training data
svm_classifier.fit(X_train_scaled, y_train)

# Predict labels for the test data
predicted_labels = svm_classifier.predict(X_test_scaled)

# Calculate accuracy on the test set
accuracy = accuracy_score(y_test, predicted_labels)

print("Accuracy of the SVM model on enhanced word embeddings:", accuracy)
# Out:
# Accuracy of the SVM model on enhanced word embeddings: 0.27867203219315895

# %%
# Create a DataFrame with a single column for predictions
test_predictions_df = pd.DataFrame({'predictions': predicted_labels})

# Save the DataFrame to a CSV file
test_predictions_df.to_csv('/content/drive/MyDrive/svm_glove_r.csv', index=False)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# Create a Logistic Regression classifier
logistic_classifier = LogisticRegression()

# Fit the classifier on the training data
logistic_classifier.fit(X_train_scaled, train['label'])

# Predict labels for the test data
predicted_labels = logistic_classifier.predict(X_test_scaled)

# Calculate accuracy on the test set
accuracy = accuracy_score(test['label'], predicted_labels)

print("Accuracy of the Logistic Regression model:", accuracy)
# Out:
# Accuracy of the Logistic Regression model: 0.323943661971831
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# Create a DataFrame with a single column for predictions
test_predictions_df = pd.DataFrame({'predictions': predicted_labels})

# Save the DataFrame to a CSV file
test_predictions_df.to_csv('/content/drive/MyDrive/lr_glove_r.csv', index=False)

# %% [markdown]
# # using pp

# %%
# Define a function to create text embeddings
def text_to_embedding(text):
    words = text.split()
    embeddings = [word_vectors.get(word, np.zeros(100)) for word in words]  # 100 is the embedding dimension
    # Handle empty or invalid text
    if not embeddings:
        return np.zeros(100)  # Return a zero vector
    return np.mean(embeddings, axis=0)  # Average the word vectors to get the text embedding

# Apply the text_to_embedding function to create embeddings for your text data
X_train_embeddings = np.array([text_to_embedding(text) for text in X_train['ptext']])
X_test_embeddings = np.array([text_to_embedding(text) for text in X_test['ptext']])

# Standardize the data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_embeddings)
X_test_scaled = scaler.transform(X_test_embeddings)

# %%
# Create an SVM classifier
svm_classifier = SVC(kernel='linear')

# Fit the classifier on the training data
svm_classifier.fit(X_train_scaled, y_train)

# Predict labels for the test data
predicted_labels = svm_classifier.predict(X_test_scaled)

# Calculate accuracy on the test set
accuracy = accuracy_score(y_test, predicted_labels)

print("Accuracy of the SVM model on enhanced word embeddings:", accuracy)
# Out:
# Accuracy of the SVM model on enhanced word embeddings: 0.272635814889336

# %%
# Create a DataFrame with a single column for predictions
test_predictions_df = pd.DataFrame({'predictions': predicted_labels})

# Save the DataFrame to a CSV file
test_predictions_df.to_csv('/content/drive/MyDrive/svm_glove_pp_r.csv', index=False)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# Create a Logistic Regression classifier
logistic_classifier = LogisticRegression()

# Fit the classifier on the training data
logistic_classifier.fit(X_train_scaled, train['label'])

# Predict labels for the test data
predicted_labels = logistic_classifier.predict(X_test_scaled)

# Calculate accuracy on the test set
accuracy = accuracy_score(test['label'], predicted_labels)

print("Accuracy of the Logistic Regression model:", accuracy)
# Out:
# Accuracy of the Logistic Regression model: 0.317907444668008
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# Create a DataFrame with a single column for predictions
test_predictions_df = pd.DataFrame({'predictions': predicted_labels})

# Save the DataFrame to a CSV file
test_predictions_df.to_csv('/content/drive/MyDrive/lr_glove_pp_r.csv', index=False)

# %% [markdown]
# # another

# %% [markdown]
# # using n-grams

# %%
# Create TF-IDF vectors for unigrams (individual words) and bigrams (n-grams of size 2)
#vectorizer = TfidfVectorizer(ngram_range=(1, 4), min_df=5, max_df=0.8, sublinear_tf=True, use_idf=True)

# Fit and transform the text data using the vectorizer
#tfidf_features = vectorizer.fit_transform(data['text'])

# %%
#X_train, X_test, y_train, y_test = train_test_split(tfidf_features, data['label'], test_size=0.2,stratify=data['label'], random_state=42)

# %%
# Train an SVM classifier on the TF-IDF vectors with n-grams
#svm_classifier = SVC(kernel='linear')
#svm_classifier.fit(X_train, y_train)

# Predict labels for the test data
#predicted_labels = svm_classifier.predict(X_test)

# Calculate accuracy on the test set
#accuracy = accuracy_score(y_test, predicted_labels)
#print("Accuracy with TF-IDF and n-grams:", accuracy)

# %% [markdown]
# ##### Accuracy with TF-IDF and n-grams: 0.136
# poor results
